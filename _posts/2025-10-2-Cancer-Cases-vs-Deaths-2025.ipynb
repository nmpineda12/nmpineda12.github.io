# %% [markdown]
# <a href="https://colab.research.google.com/github/nmpineda12/nmpineda12.github.io/blob/main/2025_10_2_Cancer_Cases_vs_Deaths_2025_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define x range
x = np.linspace(-2, 6, 400)

# Define functions
f = 2 * x + 1                    # Linear
g = x**2 - 4 * x + 3             # Quadratic

# Create the plot
plt.figure(figsize=(8, 5))

# Plot linear function
plt.plot(x, f, 'b--o', label='f(x) = 2x + 1', markevery=20)

# Plot quadratic function
plt.plot(x, g, 'r-', label='g(x) = x² - 4x + 3')

# Add labels, title, legend, and grid
plt.title('Linear vs Quadratic Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define x values
x = np.linspace(0, 10, 400)

# Define functions
f = np.sin(x)
g = np.exp(0.3 * x)

# Create side-by-side subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot sine function
axs[0].plot(x, f, 'g--', label='f(x) = sin(x)')
axs[0].set_title('Sine Function')
axs[0].set_xlabel('x')
axs[0].set_ylabel('f(x)')
axs[0].legend()
axs[0].grid(True)

# Plot exponential function
axs[1].plot(x, g, 'm-s', label='g(x) = e^{0.3x}', markevery=20)
axs[1].set_title('Exponential Function')
axs[1].set_xlabel('x')
axs[1].set_ylabel('g(x)')
axs[1].legend()
axs[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
from google.colab import files

# This will open a file picker so you can choose your Excel file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcd06362-6a93-486d-9fc3-c4bb24a659d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcd06362-6a93-486d-9fc3-c4bb24a659d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("cancer_cases_deaths_2025.xlsx")

# %%
print(df.head())
# Out:
#    Unnamed: 0  Rank    Common Type of Cancers Estimated New Cases 2025  \
# 0         NaN   1.0    Breast Cancer (Female)                   316950
# 1         NaN   2.0           Prostate Cancer                   313780
# 2         NaN   3.0  Lung and Bronchus Cancer                   226650
# 3         NaN   4.0         Colorectal Cancer                   154270
# 4         NaN   5.0      Melanoma of the Skin                   104960
#
#   Estimated Deaths 2025
# 0                 42170
# 1                 35770
# 2                124730
# 3                 52900
# 4                  8430

# %%
cases = df["Estimated New Cases 2025"].replace('-', 0, errors='coerce').astype(float).sum()
deaths = df["Estimated Deaths 2025"].replace('-', 0, errors='coerce').astype(float).sum()

values = [cases, deaths]
labels = ["Estimated New Cases 2025", "Estimated Deaths 2025"]
colors = ["skyblue", "#FA8072"]

plt.figure(figsize=(6,6))
plt.pie(values, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("Cancer Cases vs Deaths 2025")
plt.show()
# Out:
# /tmp/ipython-input-3129294365.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cases = df["Estimated New Cases 2025"].replace('-', 0).sum()
# /tmp/ipython-input-3129294365.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   deaths = df["Estimated Deaths 2025"].replace('-', 0).sum()

# %%
df["Estimated New Cases 2025"] = pd.to_numeric(df["Estimated New Cases 2025"], errors="coerce")
df["Estimated Deaths 2025"] = pd.to_numeric(df["Estimated Deaths 2025"], errors="coerce")

plt.figure(figsize=(12,6))
bar_width = 0.4
x = range(len(df))

plt.bar(x, df["Estimated New Cases 2025"], width=bar_width, label="Cases", color="skyblue")
plt.bar([i + bar_width for i in x], df["Estimated Deaths 2025"], width=bar_width, label="Deaths", color="salmon")

plt.xticks([i + bar_width/2 for i in x], df["Common Type of Cancers"], rotation=90)
plt.xlabel("Cancer Type")
plt.ylabel("Number of People")
plt.title("Estimated Cancer Cases vs Deaths (2025)")
plt.legend()
plt.tight_layout()
plt.show()
